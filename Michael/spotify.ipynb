# %%
# importing the required libraries  
import csv  
import json 
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df.head(20)
# Out:
#     Index  Position                  Track Name            Artist  Streams  \
# 0       1         1  Reggaetón Lento (Bailemos)              CNCO    19272
# 1       2         2                    Chantaje           Shakira    19270
# 2       3         3   Otra Vez (feat. J Balvin)     Zion & Lennox    15761
# 3       4         4                Vente Pa' Ca      Ricky Martin    14954
# 4       5         5                      Safari          J Balvin    14269
# 5       6         6                La Bicicleta      Carlos Vives    12843
# 6       7         7                  Ay Mi Dios          IAmChino    10986
# 7       8         8          Andas En Mi Cabeza     Chino & Nacho    10653
# 8       9         9                 Traicionera   Sebastian Yatra     9807
# 9      10        10                 Shaky Shaky      Daddy Yankee     9612
# 10     11        11                  Vacaciones             Wisin     9611
# 11     12        12      Dile Que Tu Me Quieres             Ozuna     8982
# 12     13        13             Let Me Love You          DJ Snake     8834
# 13     14        14            DUELE EL CORAZON  Enrique Iglesias     8309
# 14     15        15                     Chillax           Farruko     7822
# 15     16        16              Borro Cassette            Maluma     7586
# 16     17        17                   One Dance             Drake     7472
# 17     18        18                      Closer  The Chainsmokers     7416
# 18     19        19                     Starboy        The Weeknd     7006
# 19     20        20             Desde Esa Noche            Thalía     6779
#
#                                                   URL      Date Region
# 0   https://open.spotify.com/track/3AEZUABDXNtecAO...  1/1/2017     ec
# 1   https://open.spotify.com/track/6mICuAdrwEjh6Y6...  1/1/2017     ec
# 2   https://open.spotify.com/track/3QwBODjSEzelZyV...  1/1/2017     ec
# 3   https://open.spotify.com/track/7DM4BPaS7uofFul...  1/1/2017     ec
# 4   https://open.spotify.com/track/6rQSrBHf7HlZjtc...  1/1/2017     ec
# 5   https://open.spotify.com/track/0sXvAOmXgjR2QUq...  1/1/2017     ec
# 6   https://open.spotify.com/track/6stYbAJgTszHAHZ...  1/1/2017     ec
# 7   https://open.spotify.com/track/5mey7CLLuFToM2P...  1/1/2017     ec
# 8   https://open.spotify.com/track/5J1c3M4EldCfNxX...  1/1/2017     ec
# 9   https://open.spotify.com/track/58IL315gMSTD37D...  1/1/2017     ec
# 10  https://open.spotify.com/track/3dQDid3IUNhZy1O...  1/1/2017     ec
# 11  https://open.spotify.com/track/20ZAJdsKB5IGbGj...  1/1/2017     ec
# 12  https://open.spotify.com/track/4pdPtRcBmOSQDlJ...  1/1/2017     ec
# 13  https://open.spotify.com/track/6YZdkObH88npeKr...  1/1/2017     ec
# 14  https://open.spotify.com/track/1lxswgIpzV6HhEN...  1/1/2017     ec
# 15  https://open.spotify.com/track/6DUdDIRgLqCGq1D...  1/1/2017     ec
# 16  https://open.spotify.com/track/1xznGGDReH1oQq0...  1/1/2017     ec
# 17  https://open.spotify.com/track/7BKLCZ1jbUBVqRi...  1/1/2017     ec
# 18  https://open.spotify.com/track/5aAx2yezTd8zXrk...  1/1/2017     ec
# 19  https://open.spotify.com/track/1pWYnQIlqxTh5bx...  1/1/2017     ec

# %%
df["Region"].value_counts()
# Out:
# it    74200
# de    74200
# no    74200
# ar    74200
# tw    74200
# nz    74200
# fi    74200
# us    74200
# tr    74200
# ec    74200
# ph    74200
# fr    74200
# cr    74200
# sv    38893
# lt    16799
# cl    15460
# ee    12823
# Name: Region, dtype: int64

# %%
df.loc[(df["Region"]=='it'), "Region"]="Italy"
df.loc[(df["Region"]=='de'), "Region"]="Denmark"
df.loc[(df["Region"]=='no'), "Region"]="Norway"
df.loc[(df["Region"]=='ar'), "Region"]="Argentina"
df.loc[(df["Region"]=='tw'), "Region"]="Taiwan"
df.loc[(df["Region"]=='nz'), "Region"]="New Zealand"
df.loc[(df["Region"]=='fi'), "Region"]="Finland"
df.loc[(df["Region"]=='us'), "Region"]="US"
df.loc[(df["Region"]=='tr'), "Region"]="Turkey"
df.loc[(df["Region"]=='ec'), "Region"]="Ecuador"
df.loc[(df["Region"]=='ph'), "Region"]="Phillippines"
df.loc[(df["Region"]=='fr'), "Region"]="France"
df.loc[(df["Region"]=='cr'), "Region"]="Costa Rica"
df.loc[(df["Region"]=='sv'), "Region"]="El Salvador"
df.loc[(df["Region"]=='lt'), "Region"]="Lithuania"
df.loc[(df["Region"]=='cl'), "Region"]="Chile"
df.loc[(df["Region"]=='ee'), "Region"]="Estonia"

# %%
df.drop('Index', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Position                  Track Name         Artist  Streams  \
# 0         1  Reggaetón Lento (Bailemos)           CNCO    19272
# 1         2                    Chantaje        Shakira    19270
# 2         3   Otra Vez (feat. J Balvin)  Zion & Lennox    15761
# 3         4                Vente Pa' Ca   Ricky Martin    14954
# 4         5                      Safari       J Balvin    14269
#
#                                                  URL      Date   Region
# 0  https://open.spotify.com/track/3AEZUABDXNtecAO...  1/1/2017  Ecuador
# 1  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  1/1/2017  Ecuador
# 2  https://open.spotify.com/track/3QwBODjSEzelZyV...  1/1/2017  Ecuador
# 3  https://open.spotify.com/track/7DM4BPaS7uofFul...  1/1/2017  Ecuador
# 4  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  1/1/2017  Ecuador

# %%
df.to_csv("spotify.csv", index=False)

# %%
# defining the function to convert CSV file to JSON file  
def convjson(csvFilename, jsonFilename):  
      
    # creating a dictionary  
    mydata = {}  
      
    # reading the data from CSV file  
    with open(csvFilename, encoding = 'utf-8') as csvfile:  
        csvRead = csv.DictReader(csvfile)  
          
        # Converting rows into dictionary and adding it to data  
        for rows in csvRead:  
              
            mykey = rows['URL']  
            mydata[mykey] = rows  
  
    # dumping the data  
    with open(jsonFilename, 'w', encoding = 'utf-8') as jsonfile:  
        jsonfile.write(json.dumps(mydata, indent = 4))  
  
# filenames       
csvFilename = r'data.csv'  
jsonFilename = r'data3.json'  
  
# Calling the convjson function  
convjson(csvFilename, jsonFilename)
