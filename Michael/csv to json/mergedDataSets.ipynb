# %%
#Dependencies
import pandas as pd

# %%
#Store filepaths into variables
file_one = "data.csv"
file_two = "SpotifyFeatures.csv"

# Read our Data files with the pandas library
mainData = pd.read_csv(file_one)
featuresData = pd.read_csv(file_two)

# %%
#November pandas dataframe
mainData.head()
# Out:
#    Position                  Track Name         Artist  Streams  \
# 0         1  Reggaetón Lento (Bailemos)           CNCO    19272
# 1         2                    Chantaje        Shakira    19270
# 2         3   Otra Vez (feat. J Balvin)  Zion & Lennox    15761
# 3         4                Vente Pa' Ca   Ricky Martin    14954
# 4         5                      Safari       J Balvin    14269
#
#                                                  URL        Date Region
# 0  https://open.spotify.com/track/3AEZUABDXNtecAO...  2017-01-01     ec
# 1  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  2017-01-01     ec
# 2  https://open.spotify.com/track/3QwBODjSEzelZyV...  2017-01-01     ec
# 3  https://open.spotify.com/track/7DM4BPaS7uofFul...  2017-01-01     ec
# 4  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  2017-01-01     ec

# %%
#December pandas dataframe
featuresData.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
featuresData.rename(columns={'artist_name':'Artist'}, inplace=True)
featuresData.head()
# Out:
#    genre             Artist                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
featuresData.rename(columns={'track_name':'Track Name'}, inplace=True)
featuresData.head()
# Out:
#    genre             Artist                        Track Name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
featuresData.index
# Out:
# RangeIndex(start=0, stop=232725, step=1)

# %%
mainData.index
# Out:
# RangeIndex(start=0, stop=3441197, step=1)

# %%
mainData.set_index('Track Name', inplace=True)
mainData.head()
# Out:
#                             Position         Artist  Streams  \
# Track Name
# Reggaetón Lento (Bailemos)         1           CNCO    19272
# Chantaje                           2        Shakira    19270
# Otra Vez (feat. J Balvin)          3  Zion & Lennox    15761
# Vente Pa' Ca                       4   Ricky Martin    14954
# Safari                             5       J Balvin    14269
#
#                                                                           URL  \
# Track Name
# Reggaetón Lento (Bailemos)  https://open.spotify.com/track/3AEZUABDXNtecAO...
# Chantaje                    https://open.spotify.com/track/6mICuAdrwEjh6Y6...
# Otra Vez (feat. J Balvin)   https://open.spotify.com/track/3QwBODjSEzelZyV...
# Vente Pa' Ca                https://open.spotify.com/track/7DM4BPaS7uofFul...
# Safari                      https://open.spotify.com/track/6rQSrBHf7HlZjtc...
#
#                                   Date Region
# Track Name
# ...

# %%
featuresData.set_index('Track Name', inplace=True)
featuresData.head()
# Out:
#                                   genre             Artist  \
# Track Name
# C'est beau de faire un Show       Movie     Henri Salvador
# Perdu d'avance (par Gad Elmaleh)  Movie  Martin & les fées
# Don't Let Me Be Lonely Tonight    Movie    Joseph Williams
# Dis-moi Monsieur Gordon Cooper    Movie     Henri Salvador
# Ouverture                         Movie       Fabien Nataf
#
#                                                 track_id  popularity  \
# Track Name
# C'est beau de faire un Show       0BRjO6ga9RKCKjfDqeFgWV           0
# Perdu d'avance (par Gad Elmaleh)  0BjC1NfoEOOusryehmNudP           1
# Don't Let Me Be Lonely Tonight    0CoSDzoNIKCRs124s9uTVy           3
# Dis-moi Monsieur Gordon Cooper    0Gc6TVm52BwZD07Ki6tIvf           0
# Ouverture                         0IuslXpMROHdEPvSl1fTQK           4
#
#                                   acousticness  danceability  duration_ms  \
# Track Name
# C'est beau de faire un Show              0.611         0.389        99373
# ...

# %%
featuresData.index
# Out:
# Index(['C'est beau de faire un Show', 'Perdu d'avance (par Gad Elmaleh)',
#        'Don't Let Me Be Lonely Tonight', 'Dis-moi Monsieur Gordon Cooper',
#        'Ouverture', 'Le petit souper aux chandelles',
#        'Premières recherches (par Paul Ventimila, Lorie Pester, Véronique Jannot, Michèle Laroque & Gérard Lenorman)',
#        'Let Me Let Go', 'Helka', 'Les bisous des bisounours',
#        ...
#        'Down', 'Quickly (feat. Brandy)', 'P.O.P.',
#        'I Just Want To Make Love To You - Electric Mud Album Version',
#        'I'll Take Care Of You - Single Version', 'Son Of Slide',
#        'Burning Fire', '(I'm Your) Hoochie Coochie Man', 'With My Words',
#        'You Don't Have To Hurt No More'],
#       dtype='object', name='Track Name', length=232725)

# %%
mainData.index
# Out:
# Index([   'Reggaetón Lento (Bailemos)',                      'Chantaje',
#            'Otra Vez (feat. J Balvin)',                  'Vente Pa' Ca',
#                               'Safari',                  'La Bicicleta',
#                           'Ay Mi Dios',            'Andas En Mi Cabeza',
#                          'Traicionera',                   'Shaky Shaky',
#        ...
#        '我多喜歡你,你會知道 - 網劇《致我們單純的小美好》推廣曲',                          '富士山下',
#                        'Unforgettable',            'Castle on the Hill',
#                    'Whatever It Takes',            'More Than You Know',
#                               'Issues',                   'Tuo Fei Lun',
#                                   '面具',                    'Let Her Go'],
#       dtype='object', name='Track Name', length=3441197)

# %%
joined_df1 = mainData.merge(featuresData, how='left', left_index=True, right_index=True)
joined_df1
# Out:
#                                            Position        Artist_x  Streams  \
# Track Name
# "All That Is or Ever Was or Ever Will Be"       198  Alan Silvestri     3764
# "All That Is or Ever Was or Ever Will Be"       185  Alan Silvestri     3547
# "Read All About It, Pt. III"                    175     Emeli Sandé     9925
# "Read All About It, Pt. III"                    186     Emeli Sandé     3075
# "Read All About It, Pt. III"                    192     Emeli Sandé     3053
# ...                                             ...             ...      ...
# NaN                                              55             NaN     5413
# NaN                                              87             NaN     3426
# NaN                                              76             NaN     3082
# NaN                                              81             NaN     3397
# NaN                                             187             NaN     1997
#
# ...

# %%
joined_df = mainData.join(featuresData, how='left')
joined_df.head()
