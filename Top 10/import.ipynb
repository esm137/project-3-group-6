# %%
import sqlalchemy
from sqlalchemy import create_engine
import pandas as pd

# %%
#change if your password or database name are different
engine = create_engine(f'postgresql://postgres:password@localhost/project_3')

# %%
#change if your file path is different
df=pd.read_csv('Data.csv',low_memory=False)
df
# Out:
#          Position                  Track Name              Artist  Streams  \
# 0               1  Reggaetón Lento (Bailemos)                CNCO    19272
# 1               2                    Chantaje             Shakira    19270
# 2               3   Otra Vez (feat. J Balvin)       Zion & Lennox    15761
# 3               4                Vente Pa' Ca        Ricky Martin    14954
# 4               5                      Safari            J Balvin    14269
# ...           ...                         ...                 ...      ...
# 3441192       196          More Than You Know  Axwell /\ Ingrosso     2126
# 3441193       197                      Issues      Julia Michaels     2117
# 3441194       198                 Tuo Fei Lun          Eason Chan     2112
# 3441195       199                          面具          Alfred Hui     2102
# 3441196       200                  Let Her Go           Passenger     2088
#
# ...

# %%
df.loc[(df["Region"]=='it'), "Region"]="Italy"
df.loc[(df["Region"]=='de'), "Region"]="Denmark"
df.loc[(df["Region"]=='no'), "Region"]="Norway"
df.loc[(df["Region"]=='ar'), "Region"]="Argentina"
df.loc[(df["Region"]=='tw'), "Region"]="Taiwan"
df.loc[(df["Region"]=='nz'), "Region"]="New Zealand"
df.loc[(df["Region"]=='fi'), "Region"]="Finland"
df.loc[(df["Region"]=='us'), "Region"]="United States"
df.loc[(df["Region"]=='tr'), "Region"]="Turkey"
df.loc[(df["Region"]=='ec'), "Region"]="Ecuador"
df.loc[(df["Region"]=='ph'), "Region"]="Phillippines"
df.loc[(df["Region"]=='fr'), "Region"]="France"
df.loc[(df["Region"]=='cr'), "Region"]="Costa Rica"
df.loc[(df["Region"]=='sv'), "Region"]="El Salvador"
df.loc[(df["Region"]=='lt'), "Region"]="Lithuania"
df.loc[(df["Region"]=='cl'), "Region"]="Chile"
df.loc[(df["Region"]=='ee'), "Region"]="Estonia"
df.loc[(df["Region"]=='at'), "Region"]="Austria"
df.loc[(df["Region"]=='au'), "Region"]="Australia"
df.loc[(df["Region"]=='be'), "Region"]="Belgium"
df.loc[(df["Region"]=='bo'), "Region"]="Bolivia"
df.loc[(df["Region"]=='br'), "Region"]="Brazil"
df.loc[(df["Region"]=='ca'), "Region"]="Canada"
df.loc[(df["Region"]=='ch'), "Region"]="Switzerland"
df.loc[(df["Region"]=='co'), "Region"]="Colombia"
df.loc[(df["Region"]=='cz'), "Region"]="Czechia"
df.loc[(df["Region"]=='dk'), "Region"]="Denmark"
df.loc[(df["Region"]=='do'), "Region"]="Dominican Republic"
df.loc[(df["Region"]=='es'), "Region"]="Spain"
df.loc[(df["Region"]=='gb'), "Region"]="United Kingdom"
df.loc[(df["Region"]=='gr'), "Region"]="Greece"
df.loc[(df["Region"]=='hk'), "Region"]="Hong Kong"
df.loc[(df["Region"]=='hn'), "Region"]="Honduras"
df.loc[(df["Region"]=='hu'), "Region"]="Hungary"
df.loc[(df["Region"]=='id'), "Region"]="Indonesia"
df.loc[(df["Region"]=='ie'), "Region"]="Ireland"
df.loc[(df["Region"]=='is'), "Region"]="Israel"
df.loc[(df["Region"]=='jp'), "Region"]="Japan"
df.loc[(df["Region"]=='lu'), "Region"]="Luxembourg"
df.loc[(df["Region"]=='lv'), "Region"]="Latvia"
df.loc[(df["Region"]=='mx'), "Region"]="Mexico"
df.loc[(df["Region"]=='my'), "Region"]="Malaysia"
df.loc[(df["Region"]=='nl'), "Region"]="Netherlands"
df.loc[(df["Region"]=='pa'), "Region"]="Panama"
df.loc[(df["Region"]=='pe'), "Region"]="Peru"
df.loc[(df["Region"]=='pl'), "Region"]="Poland"
df.loc[(df["Region"]=='pt'), "Region"]="Portugal"
df.loc[(df["Region"]=='py'), "Region"]="Paraguay"
df.loc[(df["Region"]=='se'), "Region"]="Sweden"
df.loc[(df["Region"]=='sg'), "Region"]="Singapore"
df.loc[(df["Region"]=='sk'), "Region"]="Slovakia"
df.loc[(df["Region"]=='uy'), "Region"]="Uruguay"
df.loc[(df["Region"]=='gt'), "Region"]="Guatemala"

# %%
with engine.begin() as connection:
    df.to_sql('spotify_tracks', con=connection, if_exists='replace')
